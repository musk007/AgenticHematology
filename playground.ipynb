# %%
import os

# %%
data_folder = "/Volumes/One Touch/Data/Hematology/Large Leukemia Dataset/Leukemia_Attr/LeukemiaAttri_Dataset 4/H_40X_C2/Images/train"

# %%
patients = []
splits = ["", " 2", " 3", " 4", " 5"]
for split in splits:
    data_folder = f"/Volumes/One Touch/Data/Hematology/Large Leukemia Dataset/Leukemia_Attr/LeukemiaAttri_Dataset{split}/H_40X_C2/Images/test"
    try:
        for im in os.listdir(data_folder):
            pat = im.split("_")[0]
            patients.append(pat)
    except:
        print(f"The split at {split} has no test images")

# %%
len(set(patients))
# Out:
# 14

# %%
set(patients)
# Out:
# {'.',
#  '15',
#  '18',
#  '21',
#  '23',
#  '28',
#  '31',
#  '34',
#  '4',
#  '40',
#  '43',
#  '45',
#  '6',
#  '8'}

# %%
{'1', '10', '11', '12', '13', '14', '16', '17', '19', '2', '20', '22', '24', 
'25', '27', '29', '3', '30', '32', '33', '35', '36', '37', '38', '39', '41', 
'42', '44', '46', '47', '48','5', '7', '9'}
{'15', '18', '21', '23', '28', '31', '34', '4', '40', '43', '45', '6', '8'}
